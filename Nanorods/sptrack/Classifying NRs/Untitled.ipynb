# %%
from numpy import *
from numpy.random import rand,randn
import matplotlib.pylab as plt
import matplotlib.style as style
# %matplotlib inline

# %%
import matplotlib
matplotlib.get_configdir()
# Out:
# '/users/bssn/serna/.config/matplotlib'

# %%
plt.style.use('default')
for i in range(4):
    xc = rand()
    yc = rand()
    plt.plot(xc+randn(20)*0.05,yc+randn(20)*0.05,'.')
